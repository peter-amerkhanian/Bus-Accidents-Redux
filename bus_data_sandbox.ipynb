# %%
import pandas as pd
pd.options.display.float_format = '{:,.0f}'.format
pd.set_option('display.max_colwidth', -1)

# %%
data = pd.read_csv("test.csv")

# %%
data.head()
# Out:
#    Unnamed: 0        date  deaths  \
# 0  0           2016-12-08  13
# 1  1           2016-12-08  14
# 2  2           2017-01-03  1
# 3  3           2017-01-14  20
# 4  4           2017-01-21  1
#
#                                                                                                                                                                                                                                                                 epi  \
# 0  Un bus interprovincial, que cubría la ruta Tulcán-Quito rodó a un precipicio de aproximadamente 100 metros de profundidad, en la carretera Panamericana Norte, a la altura del sector de Oyacoto, en el km. 6.
# 1  La Universidad Técnica del Norte (UTN), de la ciudad de Ibarra, provincia de Imbabura, situada en el norte de Ecuador, está de luto.
# ...

# %%
data.groupby('date').agg({'deaths': 'last',
                         'epi': 'first',
                         'route': 'first',
                         'time': 'first',
                         'url': 'first'}).head()
# Out:
#             deaths  \
# date
# 2016-12-08  14
# 2017-01-03  1
# 2017-01-14  20
# 2017-01-21  1
# 2017-02-04  3
#
#                                                                                                                                                                                                                                                                          epi  \
# date
# 2016-12-08  Un bus interprovincial, que cubría la ruta Tulcán-Quito rodó a un precipicio de aproximadamente 100 metros de profundidad, en la carretera Panamericana Norte, a la altura del sector de Oyacoto, en el km. 6.
# 2017-01-03  Un bus de transporte interprovincial se accidentó en el kilómetro 30 de la vía Ambato-Guaranda (Sierra centro del Ecuador ) hoy, martes 3 de enero del 2017. Según el Sistema de Seguridad ECU 911 de Ambato, el volcamiento de la unidad ocurrió a las 03:45.
# ...

# %%
## Test Work
# for index, date in enumerate(data.date):
#     for second_date in data.date[index+1:]:
#         if date == second_date:
#             print(data.loc[data['date'] == date].date, data.loc[data['date'] == date].epi)
            
#             print(data.loc[data['date'] == second_date].date, data.loc[data['date'] == second_date].epi)
#     print("\n")
